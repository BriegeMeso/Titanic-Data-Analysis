# %% [markdown]
# Project questiions.
# - is there a relationship between survival and age?
# - is there a correlation between sex and survival?
# - Survival rate by gender/class
#
# - Chi-square tests (Sex vs Survival)
#
# - T-tests (Age vs Survival)
#
# - Correlation analysis

# %% [markdown]
# Loading the dataset

# %%
import pandas as pd
import numpy as np


df = pd.read_csv('titanic.csv', index_col=0) # index_col removed the redundant column Unnamed=0
df
# Out:
#      PassengerId  Survived Pclass  \
# 0              1         0      3
# 1              2         1      1
# 2              3         1      3
# 3              4         1      1
# 4              5         0      3
# ..           ...       ...    ...
# 886          887         0      2
# 887          888         1      1
# 888          889         0      ?
# 889          890         1      1
# 890          891         0      3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Inspecting the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    object
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 90.5+ KB

# %% [markdown]
# The dataset has 12 columns. Some columns have all the data while others have some missing values. The columns also have different data types.

# %%
df.head()
# Out:
#    PassengerId  Survived Pclass  \
# 0            1         0      3
# 1            2         1      1
# 2            3         1      3
# 3            4         1      1
# 4            5         0      3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# Identifying missing values

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# percentage of missing data 
(df.isna().sum()/len(df))*100
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %% [markdown]
# From the dataset,age has 19% of its data missing, cabin 77.104% of its data missing and embarked has 0.22% missing. Therefore, we can decide if we will fill the missing values or drop them entirely.

# %% [markdown]
# Checking for duplicates

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %% [markdown]
# The dataset has no duplicates whatsover.

# %% [markdown]
# Handling missing data.

# %%
# For cabin, the whole column will be dropped.
# For Embarked since a few of its data is missing, it will be dropped.
# For Age, we can either drop or fill

column_to_drop = ['Cabin']

df = df.drop(columns=column_to_drop,axis=1)
df
# Out:
#      PassengerId  Survived Pclass  \
# 0              1         0      3
# 1              2         1      1
# 2              3         1      3
# 3              4         1      1
# 4              5         0      3
# ..           ...       ...    ...
# 886          887         0      2
# 887          888         1      1
# 888          889         0      ?
# 889          890         1      1
# 890          891         0      3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    object
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %% [markdown]
# The column Cabin has been dropped.

# %%
# For age, we are going to replace the missing values with median

df['Age'].fillna(df['Age'].median(),inplace=True)
df
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_22052\731659138.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].median(),inplace=True)
#      PassengerId  Survived Pclass  \
# 0              1         0      3
# 1              2         1      1
# 2              3         1      3
# 3              4         1      1
# 4              5         0      3
# ..           ...       ...    ...
# 886          887         0      2
# 887          888         1      1
# ...

# %%
# changing the age column to be an integer and not a float
df['Age'] = df['Age'].astype(int)
df
# Out:
#      PassengerId  Survived Pclass  \
# 0              1         0      3
# 1              2         1      1
# 2              3         1      3
# 3              4         1      1
# 4              5         0      3
# ..           ...       ...    ...
# 886          887         0      2
# 887          888         1      1
# 888          889         0      ?
# 889          890         1      1
# 890          891         0      3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                               Heikkinen, Miss. Laina  female   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                             Allen, Mr. William Henry    male   35      0
# ..                                                 ...     ...  ...    ...
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
# cleaning the embarked column
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])
df
# Out:
#      PassengerId  Survived Pclass  \
# 0              1         0      3
# 1              2         1      1
# 2              3         1      3
# 3              4         1      1
# 4              5         0      3
# ..           ...       ...    ...
# 886          887         0      2
# 887          888         1      1
# 888          889         0      ?
# 889          890         1      1
# 890          891         0      3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                               Heikkinen, Miss. Laina  female   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                             Allen, Mr. William Henry    male   35      0
# ..                                                 ...     ...  ...    ...
# ...

# %%
(df.isna().sum()/len(df))*100
# Out:
# PassengerId    0.0
# Survived       0.0
# Pclass         0.0
# Name           0.0
# Sex            0.0
# Age            0.0
# SibSp          0.0
# Parch          0.0
# Ticket         0.0
# Fare           0.0
# Embarked       0.0
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    object
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    int64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     891 non-null    object
# dtypes: float64(1), int64(5), object(5)
# memory usage: 83.5+ KB

# %%
# checking for placeholders in the columns
df['Pclass'].unique()
# Out:
# array(['3', '1', '2', '?'], dtype=object)

# %%
df['Pclass'] = df['Pclass'].replace(['0', 'Unknown', '','?'],np.nan)

# %%
df['Pclass'] = pd.to_numeric(df['Pclass'])

# %%
# handling placeholders in Pclass
df['Pclass'] = df['Pclass'].fillna(df['Pclass'].mode()[0])

# %%
df['Pclass'] = df['Pclass'].astype(int)

# %%
df['Pclass'].unique()
# Out:
# array([3, 1, 2])

# %% [markdown]
# All the colums have now been cleaned and we can proceed to data analysis.

# %% [markdown]
# DATA ANALYSIS

# %%
# Statistics

df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.355780   29.345679    0.523008
# std     257.353842    0.486592    0.825314   13.028212    1.102743
# min       1.000000    0.000000    1.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# - From the descriptive statistics, the mean age for passengers in Titanic was 29.34.
# - The average fair for passengers in Titanic was 32.204.

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %% [markdown]
# There were 577 male pasengers and 314 female passengers.

# %%
# Understanding the number of passengers in the passenger classes 
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    518
# 1    201
# 2    172
# Name: count, dtype: int64

# %%
df['Pclass'].unique()
# Out:
# array([3, 1, 2])

# %% [markdown]
# ## Do determine the relationship between sex and survival. To determine if survival depends on sex.

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# %%
# a contingency table will create a table to determine how many male/females survived and didn't survive
# Count of survivors by sex
contingency_table = pd.crosstab(df['Sex'], df['Survived'])
print(contingency_table)
# Out:
# Survived    0    1
# Sex
# female     81  233
# male      468  109

# %% [markdown]
# - From the output, 81 females died and 468 males died.
# - On the other hand, 233 females survived and 109 males survived.

# %%
chi2, p, dof, expected = chi2_contingency(contingency_table)

print("Chi-square statistic:", chi2)
print("Degrees of freedom:", dof)
print("p-value:", p)
print("Expected frequencies:\n", expected)
# Out:
# Chi-square statistic: 260.71702016732104
# Degrees of freedom: 1
# p-value: 1.1973570627755645e-58
# Expected frequencies:
#  [[193.47474747 120.52525253]
#  [355.52525253 221.47474747]]

# %% [markdown]
# From our output, the p value is so small(1.1973570627755645e-58) indicating that survival was strongly associatd with sex. From our data, many females survived as compared to males.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='Sex', hue='Survived', data=df)
plt.title('Survival Count by Sex')
plt.show()

# %% [markdown]
# ## To determine if there is a correlation between survival and age.

# %%
df.groupby('Sex').agg({'PassengerId': 'count',
                      'Survived': 'sum',
                      'Age': 'mean'})
# Out:
#         PassengerId  Survived        Age
# Sex
# female          314       233  27.920382
# male            577       109  30.121317

# %%
df[['Survived','Age']].corr()
# Out:
#           Survived       Age
# Survived  1.000000 -0.064909
# Age      -0.064909  1.000000

# %% [markdown]
# There is a weak linear relationship between Survival and Age. This also means that as age increases, survival chances tend to reduce.

# %%
df.boxplot(column='Age', by='Survived')
plt.xlabel('Survived (0 = No, 1 = Yes)')
plt.ylabel('Age')
plt.title('Age Distribution by Survival')
plt.suptitle('')
plt.show()

# %%
df[df['Survived'] == 1]['Age'].hist(alpha=0.5, label='Survived')
df[df['Survived'] == 0]['Age'].hist(alpha=0.5, label='Did not survive')
plt.legend()
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution by Survival')
plt.show()

# %% [markdown]
# ## To determine if there is a relationship between survival and passenger class

# %%
df[['Survived','Pclass']].corr()
# Out:
#           Survived    Pclass
# Survived  1.000000 -0.301264
# Pclass   -0.301264  1.000000

# %% [markdown]
# The output shows a weak linear relatioship between Survival and Passenger Class. That as Passenger class increased(1-3), the channces of survival reduces. This maybe due to the fact that first class passengers probably were given priority in the rescue mission compared to the other classes. This output is true and reflects the historical data.

# %% [markdown]
# ## T test between survival and age.
